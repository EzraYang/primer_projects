# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Customizing-plots" data-toc-modified-id="Customizing-plots-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Customizing plots</a></div><div class="lev2 toc-item"><a href="#Plotting-multiple-graphs" data-toc-modified-id="Plotting-multiple-graphs-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plotting multiple graphs</a></div><div class="lev3 toc-item"><a href="#Multiple-plots-on-single-axis" data-toc-modified-id="Multiple-plots-on-single-axis-111"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Multiple plots on single axis</a></div><div class="lev3 toc-item"><a href="#Using-axes()" data-toc-modified-id="Using-axes()-112"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Using axes()</a></div><div class="lev3 toc-item"><a href="#Using-subplot()" data-toc-modified-id="Using-subplot()-113"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Using subplot()</a></div><div class="lev2 toc-item"><a href="#Customizing-axes" data-toc-modified-id="Customizing-axes-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Customizing axes</a></div><div class="lev3 toc-item"><a href="#zooming-Using-xlim(),-ylim()" data-toc-modified-id="zooming-Using-xlim(),-ylim()-121"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>zooming Using xlim(), ylim()</a></div><div class="lev3 toc-item"><a href="#zooming-Using-axis()" data-toc-modified-id="zooming-Using-axis()-122"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>zooming Using axis()</a></div><div class="lev2 toc-item"><a href="#Legends,-annotations,-and-styles" data-toc-modified-id="Legends,-annotations,-and-styles-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Legends, annotations, and styles</a></div><div class="lev3 toc-item"><a href="#using-legend" data-toc-modified-id="using-legend-131"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>using legend</a></div><div class="lev3 toc-item"><a href="#Using-annotate()-to-add-text-or-arrow" data-toc-modified-id="Using-annotate()-to-add-text-or-arrow-132"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Using annotate() to add text or arrow</a></div><div class="lev3 toc-item"><a href="#modifying-styles" data-toc-modified-id="modifying-styles-133"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>modifying styles</a></div><div class="lev1 toc-item"><a href="#Plotting-2D-arrays" data-toc-modified-id="Plotting-2D-arrays-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plotting 2D arrays</a></div><div class="lev2 toc-item"><a href="#Working-with-2D-arrays" data-toc-modified-id="Working-with-2D-arrays-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Working with 2D arrays</a></div><div class="lev3 toc-item"><a href="#Generating-meshes" data-toc-modified-id="Generating-meshes-211"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Generating meshes</a></div><div class="lev2 toc-item"><a href="#Visualizing-bivariate-functions" data-toc-modified-id="Visualizing-bivariate-functions-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Visualizing bivariate functions</a></div><div class="lev3 toc-item"><a href="#Contour-&amp;-filled-contour-plots" data-toc-modified-id="Contour-&amp;-filled-contour-plots-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Contour &amp; filled contour plots</a></div><div class="lev3 toc-item"><a href="#Modifying-colormaps" data-toc-modified-id="Modifying-colormaps-222"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Modifying colormaps</a></div><div class="lev2 toc-item"><a href="#Visualizing-bivariate-distributions" data-toc-modified-id="Visualizing-bivariate-distributions-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Visualizing bivariate distributions</a></div><div class="lev3 toc-item"><a href="#2D-histogram-Using-hist2d()" data-toc-modified-id="2D-histogram-Using-hist2d()-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>2D histogram Using hist2d()</a></div><div class="lev3 toc-item"><a href="#2D-hexagonal-bins-Using-hexbin()" data-toc-modified-id="2D-hexagonal-bins-Using-hexbin()-232"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>2D hexagonal bins Using hexbin()</a></div><div class="lev2 toc-item"><a href="#Working-with-images" data-toc-modified-id="Working-with-images-24"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Working with images</a></div><div class="lev3 toc-item"><a href="#play-with-avatar" data-toc-modified-id="play-with-avatar-241"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>play with avatar</a></div><div class="lev3 toc-item"><a href="#Loading,-examining-images" data-toc-modified-id="Loading,-examining-images-242"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Loading, examining images</a></div><div class="lev3 toc-item"><a href="#Pseudocolor-plot-from-image-data" data-toc-modified-id="Pseudocolor-plot-from-image-data-243"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Pseudocolor plot from image data</a></div><div class="lev3 toc-item"><a href="#Extent-and-aspect" data-toc-modified-id="Extent-and-aspect-244"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Extent and aspect</a></div><div class="lev1 toc-item"><a href="#Statistical-plots-with-Seaborn" data-toc-modified-id="Statistical-plots-with-Seaborn-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Statistical plots with Seaborn</a></div><div class="lev2 toc-item"><a href="#Visualizing-regressions" data-toc-modified-id="Visualizing-regressions-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualizing regressions</a></div><div class="lev3 toc-item"><a href="#Simple-linear-regressions" data-toc-modified-id="Simple-linear-regressions-311"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Simple linear regressions</a></div><div class="lev3 toc-item"><a href="#Plotting-residuals-of-a-regression" data-toc-modified-id="Plotting-residuals-of-a-regression-312"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Plotting residuals of a regression</a></div><div class="lev3 toc-item"><a href="#Higher-order-regressions" data-toc-modified-id="Higher-order-regressions-313"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Higher-order regressions</a></div><div class="lev3 toc-item"><a href="#Grouping-linear-regressions-by-hue" data-toc-modified-id="Grouping-linear-regressions-by-hue-314"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Grouping linear regressions by hue</a></div><div class="lev3 toc-item"><a href="#Grouping-linear-regressions-by-row-or-column" data-toc-modified-id="Grouping-linear-regressions-by-row-or-column-315"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Grouping linear regressions by row or column</a></div><div class="lev2 toc-item"><a href="#Visualizing-univariate-distributions" data-toc-modified-id="Visualizing-univariate-distributions-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualizing univariate distributions</a></div><div class="lev3 toc-item"><a href="#Constructing-strip-plots" data-toc-modified-id="Constructing-strip-plots-321"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Constructing strip plots</a></div><div class="lev3 toc-item"><a href="#Constructing-swarm-plots" data-toc-modified-id="Constructing-swarm-plots-322"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Constructing swarm plots</a></div><div class="lev3 toc-item"><a href="#Constructing-violin-plots" data-toc-modified-id="Constructing-violin-plots-323"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Constructing violin plots</a></div><div class="lev2 toc-item"><a href="#Visualizing-multivariate-distributions" data-toc-modified-id="Visualizing-multivariate-distributions-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Visualizing multivariate distributions</a></div><div class="lev3 toc-item"><a href="#Plotting-joint-distributions-(1)" data-toc-modified-id="Plotting-joint-distributions-(1)-331"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Plotting joint distributions (1)</a></div><div class="lev3 toc-item"><a href="#Plotting-joint-distributions-(2),-kind-param" data-toc-modified-id="Plotting-joint-distributions-(2),-kind-param-332"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Plotting joint distributions (2), kind param</a></div><div class="lev3 toc-item"><a href="#Plotting-distributions-pairwise-(1)" data-toc-modified-id="Plotting-distributions-pairwise-(1)-333"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Plotting distributions pairwise (1)</a></div><div class="lev3 toc-item"><a href="#Plotting-distributions-pairwise-(2)" data-toc-modified-id="Plotting-distributions-pairwise-(2)-334"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Plotting distributions pairwise (2)</a></div><div class="lev3 toc-item"><a href="#Visualizing-correlations-with-a-heatmap" data-toc-modified-id="Visualizing-correlations-with-a-heatmap-335"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Visualizing correlations with a heatmap</a></div><div class="lev1 toc-item"><a href="#Analyzing-time-series-and-images" data-toc-modified-id="Analyzing-time-series-and-images-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Analyzing time series and images</a></div><div class="lev2 toc-item"><a href="#Visualizing-time-series" data-toc-modified-id="Visualizing-time-series-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Visualizing time series</a></div><div class="lev3 toc-item"><a href="#Multiple-time-series-on-common-axes" data-toc-modified-id="Multiple-time-series-on-common-axes-411"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Multiple time series on common axes</a></div><div class="lev3 toc-item"><a href="#Multiple-time-series-slices-(1)" data-toc-modified-id="Multiple-time-series-slices-(1)-412"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Multiple time series slices (1)</a></div><div class="lev3 toc-item"><a href="#Multiple-time-series-slices-(2)" data-toc-modified-id="Multiple-time-series-slices-(2)-413"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Multiple time series slices (2)</a></div><div class="lev3 toc-item"><a href="#Plotting-an-inset-view" data-toc-modified-id="Plotting-an-inset-view-414"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Plotting an inset view</a></div><div class="lev2 toc-item"><a href="#Time-series-with-moving-windows" data-toc-modified-id="Time-series-with-moving-windows-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Time series with moving windows</a></div><div class="lev3 toc-item"><a href="#Plotting-moving-averages" data-toc-modified-id="Plotting-moving-averages-421"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Plotting moving averages</a></div><div class="lev3 toc-item"><a href="#Plotting-moving-standard-deviations" data-toc-modified-id="Plotting-moving-standard-deviations-422"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Plotting moving standard deviations</a></div><div class="lev2 toc-item"><a href="#Histogram-equalization-in-images" data-toc-modified-id="Histogram-equalization-in-images-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Histogram equalization in images</a></div><div class="lev3 toc-item"><a href="#Extracting-a-histogram-from-a-grayscale-image" data-toc-modified-id="Extracting-a-histogram-from-a-grayscale-image-431"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Extracting a histogram from a grayscale image</a></div><div class="lev3 toc-item"><a href="#Cumulative-Distribution-Function-from-an-image-histogram" data-toc-modified-id="Cumulative-Distribution-Function-from-an-image-histogram-432"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Cumulative Distribution Function from an image histogram</a></div><div class="lev3 toc-item"><a href="#Equalizing-an-image-histogram" data-toc-modified-id="Equalizing-an-image-histogram-433"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Equalizing an image histogram</a></div><div class="lev3 toc-item"><a href="#Extracting-color-channels-histograms-from-a-color-image" data-toc-modified-id="Extracting-color-channels-histograms-from-a-color-image-434"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Extracting color channels histograms from a color image</a></div><div class="lev3 toc-item"><a href="#Extracting-bivariate-histograms-from-a-color-image" data-toc-modified-id="Extracting-bivariate-histograms-from-a-color-image-435"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Extracting bivariate histograms from a color image</a></div><div class="lev1 toc-item"><a href="#end" data-toc-modified-id="end-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>end</a></div>

# %%
ls
# Out:
# Untitled.ipynb
# astronaut.jpg
# auto-mpg.csv
# avatar.jpg
# hawk.jpg
# percent-bachelors-degrees-women-usa.csv
# stocks.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Customizing plots

# %% [markdown]
# ## Plotting multiple graphs

# %%
dgr = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
dgr.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
dgr.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
string = "'Year','Agriculture','Architecture','Art_and_Performance','Biology','Business','Communications_and_Journalism','Computer_Science','Education','Engineering','English','Foreign_Languages','Health_Professions','Math_and_Statistics','Physical_Sciences','Psychology','Public_Administration','Social_Sciences_and_History'"

# %%
string.lower()
# Out:
# "'year','agriculture','architecture','art_and_performance','biology','business','communications_and_journalism','computer_science','education','engineering','english','foreign_languages','health_professions','math_and_statistics','physical_sciences','psychology','public_administration','social_sciences_and_history'"

# %%
dgr.columns = ['year','agriculture','architecture','art_and_performance','biology','business','communications_and_journalism','computer_science','education','engineering','english','foreign_languages','health_professions','math_and_statistics','physical_sciences','psychology','public_administration','social_sciences_and_history']

# %% [markdown]
# ### Multiple plots on single axis

# %%
plt.plot(dgr.year, dgr.physical_sciences, color='blue')
plt.plot(dgr.year, dgr.computer_science, color='red')

plt.show()

# %% [markdown]
# ### Using axes()

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])

plt.plot(dgr.year, dgr.physical_sciences, color='blue')

plt.axes([0.525, 0.05, 0.425, 0.9])

plt.plot(dgr.year, dgr.computer_science, color='red')

plt.show()

# %% [markdown]
# ### Using subplot()

# %%
plt.subplot(1, 2, 1)

plt.plot(dgr.year, dgr.physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(1, 2, 2)

plt.plot(dgr.year, dgr.computer_science, color='red')
plt.title('Computer Science')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %%
dgr.columns
# Out:
# Index(['year', 'agriculture', 'architecture', 'art_and_performance', 'biology',
#        'business', 'communications_and_journalism', 'computer_science',
#        'education', 'engineering', 'english', 'foreign_languages',
#        'health_professions', 'math_and_statistics', 'physical_sciences',
#        'psychology', 'public_administration', 'social_sciences_and_history'],
#       dtype='object')

# %%
plt.subplot(2, 2, 1)

plt.plot(dgr.year, dgr.physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2,2,2)

plt.plot(dgr.year, dgr.computer_science, color='red')
plt.title('Computer Science')

plt.subplot(2,2,3)

plt.plot(dgr.year, dgr.health_professions, color='green')
plt.title('Health Professions')

plt.subplot(2,2,4)

plt.plot(dgr.year, dgr.education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Customizing axes

# %% [markdown]
# ### zooming Using xlim(), ylim()

# %%
plt.plot(dgr.year,dgr.computer_science, color='red') 
plt.plot(dgr.year, dgr.physical_sciences, color='blue')

plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

plt.xlim([1990, 2010])

plt.ylim([0, 50])

plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')
plt.show()

# plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# ### zooming Using axis()

# %%
plt.plot(dgr.year,dgr.computer_science, color='red') 
plt.plot(dgr.year, dgr.physical_sciences, color='blue')

plt.axis((1990, 2010,0,50))

plt.show()

# plt.savefig('axis_limits.png')

# %% [markdown]
# ## Legends, annotations, and styles

# %% [markdown]
# ### using legend

# %%
plt.plot(dgr.year, dgr.computer_science, color='red', label='Computer Science') 
plt.plot(dgr.year, dgr.physical_sciences, color='blue', label='Physical Sciences')

plt.legend(loc='lower center')

plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# ### Using annotate() to add text or arrow

# %%
plt.plot(dgr.year, dgr.computer_science, color='red', label='Computer Science') 
plt.plot(dgr.year, dgr.physical_sciences, color='blue', label='Physical Sciences')
plt.legend(loc='lower right')

cs_max = dgr.computer_science.max()

yr_max = dgr.year[dgr.computer_science == max(dgr.computer_science)]

plt.annotate('Maximum',            # text to add 
             xy=(yr_max, cs_max),  # pointing to  
             xytext=(yr_max+5, cs_max+5),  # pointing from 
             arrowprops={'color':'black'}  # set arrow color
            )

plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %%
plt.plot(dgr.year, dgr.computer_science, color='red', label='Computer Science') 
plt.plot(dgr.year, dgr.physical_sciences, color='blue', label='Physical Sciences')
plt.legend(loc='lower right')

cs_max = dgr.computer_science.max()

yr_max = dgr.year[dgr.computer_science == max(dgr.computer_science)]

plt.annotate('Maximum',            # text to add 
             xy=(yr_max, cs_max),  # pointing to  
             xytext=(yr_max-3, cs_max+1),  # text location
            )

plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# ### modifying styles

# %%
plt.style.available
# Out:
# ['seaborn-muted',
#  '_classic_test',
#  'fivethirtyeight',
#  'ggplot',
#  'seaborn-white',
#  'seaborn-dark-palette',
#  'grayscale',
#  'classic',
#  'seaborn-ticks',
#  'seaborn-deep',
#  'seaborn',
#  'seaborn-pastel',
#  'seaborn-notebook',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'seaborn-dark',
#  'seaborn-whitegrid',
#  'seaborn-paper',
#  'dark_background',
#  'bmh',
#  'seaborn-talk',
#  'seaborn-bright',
#  'seaborn-darkgrid']

# %%
plt.style.use('ggplot')

plt.subplot(2, 2, 1) 
plt.plot(dgr.year, dgr.physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2, 2, 2)
plt.plot(dgr.year, dgr.computer_science, color='red')
plt.title('Computer Science')

cs_max = dgr.computer_science.max()
yr_max = dgr.year[dgr.computer_science.argmax()]
plt.annotate('Maximum', 
             xy=(yr_max, cs_max), 
             xytext=(yr_max-1, cs_max-10), 
             arrowprops=dict(facecolor='black'))

plt.subplot(2, 2, 3)
plt.plot(dgr.year, dgr.health_professions, color='green')
plt.title('Health Professions')

plt.subplot(2, 2, 4)
plt.plot(dgr.year, dgr.education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting 2D arrays

# %% [markdown]
# ## Working with 2D arrays

# %% [markdown]
# ### Generating meshes

# %%
# how np.meshgrid works
u = np.linspace(-2, 2, 3)   # 3 numbers 
v = np.linspace(-1, 1, 5)   # 5 numbers 

X,Y = np.meshgrid(u, v)   # rep u downward(1st axis) 5 times 
                          # rep v leftward(2nd axis) 3 times

print(X)
print(Y)
# Out:
# [[-2.  0.  2.]
#  [-2.  0.  2.]
#  [-2.  0.  2.]
#  [-2.  0.  2.]
#  [-2.  0.  2.]]
# [[-1.  -1.  -1. ]
#  [-0.5 -0.5 -0.5]
#  [ 0.   0.   0. ]
#  [ 0.5  0.5  0.5]
#  [ 1.   1.   1. ]]

# %%
u = np.linspace(-2, 2, 41)  # 41 number 
v = np.linspace(-1, 1, 21)  # 21 number 

X,Y = np.meshgrid(u, v)     # two 21*41 array

Z = np.sin(3*np.sqrt(X**2 + Y**2)) 

plt.pcolor(Z)
plt.axis('off')
plt.show()

# plt.savefig('sine_mesh.png')

# %%
plt.imshow(Z)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Visualizing bivariate functions

# %% [markdown]
# ### Contour & filled contour plots

# %%
    # Generate a default contour map of the array Z
plt.subplot(2,2,1)
plt.contour(X, Y, Z)  # X, Y as axis; Z as values

    # Generate a contour map with 20 contours
plt.subplot(2,2,2)
plt.contour(X, Y, Z, 10)

    # Generate a default filled contour map of the array Z
plt.subplot(2,2,3)
plt.contourf(X, Y, Z)

    # Generate a default filled contour map with 20 contours
plt.subplot(2,2,4)
plt.contourf(X, Y, Z, 10)

    # Improve the spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Modifying colormaps
# You can insert the option cmap='name' into most matplotlib functions to change the color map of the resulting plot.
#
# * Some matplotlib colormaps have unique names such as 'jet', 'coolwarm', 'magma' and 'viridis'.
# * Others have a naming scheme based on overall color such as 'Greens', 'Blues', 'Reds', and 'Purples'.
# * Another four colormaps are based on the seasons, namely 'summer', 'autumn', 'winter' and 'spring'.

# %%
plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')

plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='gray')
plt.colorbar()
plt.title('Gray')

plt.subplot(2,2,3)
plt.contourf(X, Y, Z, 20 , cmap='autumn')
plt.colorbar()
plt.title('Autumn')

plt.subplot(2,2,4)
plt.contourf(X, Y, Z, 20 , cmap='winter')
plt.colorbar()
plt.title('Winter')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing bivariate distributions

# %% [markdown]
# ### 2D histogram Using hist2d()

# %%
auto = pd.read_csv('auto-mpg.csv')
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %%
sns.set_palette("husl")

plt.hist2d(auto.hp, auto.mpg,          # variable on x-axis and y-axis
           bins=(20, 20),    # num. of bins along x-axis and y-axis
           range=((40, 235), (8, 48)) # ((xlow, xhigh), (ylow, yhigh))
          )

plt.colorbar()

plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hist2d() plot')
plt.show()

# %% [markdown]
# ### 2D hexagonal bins Using hexbin()

# %%
plt.hexbin(auto.hp, auto.mpg, 
           gridsize=(15, 12),     # similiar to 'bins' in hist2d()
           extent=(40,235, 8, 48) # similiar to 'range' in hist2d()
          )

           
plt.colorbar()

plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hexbin() plot')
plt.axis('tight')
plt.show()

# %% [markdown]
# ## Working with images

# %% [markdown]
# ### play with avatar

# %% [markdown]
# * To read an image from file, use plt.imread() by passing the path to a file, such as a PNG or JPG file.
# * The color image can be plotted as usual using plt.imshow().
# * The resulting image loaded is a NumPy array of three dimensions. The array typically has dimensions M×N×3M×N×3, where M×NM×N is the dimensions of the image. The third dimensions are referred to as color channels (typically red, green, and blue).
# * The color channels can be extracted by Numpy array slicing.

# %%
avt = plt.imread('avatar.jpg')
print(avt.shape)

plt.imshow(avt)
plt.axis('off')
# Out:
# (1080, 1080, 3)
# (-0.5, 1079.5, 1079.5, -0.5)

# %%
    # play with cmap
collapsed = avt.mean(axis=2) # condense 3 layer to only 1 
print(collapsed.shape)

cmaps = ['jet', 'coolwarm', 'magma', 'viridis', 
         'Greens', 'Blues', 'Reds', 'Purples', 
         'spring', 'summer', 'autumn', 'winter']

for i in range(12):
        plt.subplot(3,4,i+1)
        plt.set_cmap(cmaps[i])
        plt.imshow(collapsed, cmap=cmaps[i])
        plt.axis('off')
    
plt.show()
# Out:
# (1080, 1080)

# %%
uneven = collapsed[::4, ::2] # every 4th ele row-wise; 
                             # every 2th ele col-wise
print(uneven.shape)

plt.subplot(2, 1, 1)
plt.imshow(uneven, cmap='coolwarm')
plt.axis('off')

plt.subplot(2,1,2)
plt.imshow(uneven, cmap='coolwarm', 
           aspect=2.0    # height-to-width ratio of each pixel
          )
plt.axis('off')
# Out:
# (270, 540)
# (-0.5, 539.5, 269.5, -0.5)

# %% [markdown]
# ### Loading, examining images

# %%
astr = plt.imread('astronaut.jpg')
astr.shape
# Out:
# (3072, 3072, 3)

# %%
astr = astr[::7, ::7]
astr.shape
# Out:
# (439, 439, 3)

# %%
plt.imshow(astr)
plt.axis('off')
# Out:
# (-0.5, 438.5, 438.5, -0.5)

# %% [markdown]
# ### Pseudocolor plot from image data

# %%
astr_intense = astr.mean(axis=2)

print(astr_intense.shape)

plt.imshow(astr_intense, cmap='gray')

plt.colorbar()

plt.axis('off')
# Out:
# (439, 439)
# (-0.5, 438.5, 438.5, -0.5)

# %% [markdown]
# ### Extent and aspect

# %%
plt.subplot(2,2,1)
plt.title('extent=(-1,1,-1,1),\naspect=0.5') 
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(astr, extent=(-1,1,-1,1), aspect=0.5)

plt.subplot(2,2,2)
plt.title('extent=(-1,1,-1,1),\naspect=1')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(astr, extent=(-1,1,-1,1),aspect=1)

plt.subplot(2,2,3)
plt.title('extent=(-1,1,-1,1),\naspect=2')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(astr, extent=(-1,1,-1,1),aspect=2)

plt.subplot(2,2,4)
plt.title('extent=(-2,2,-1,1),\naspect=2')
plt.xticks([-2,-1,0,1,2])
plt.yticks([-1,0,1])
plt.imshow(astr, extent=(-2,2,-1,1),aspect=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistical plots with Seaborn

# %% [markdown]
# As you have seen, seaborn provides a convenient interface to generate complex and great-looking statistical plots. One of the simplest things you can do using seaborn is to fit and visualize a simple linear regression between two variables using sns.lmplot().
#
# One difference between seaborn and regular matplotlib plotting is that you can pass pandas DataFrames directly to the plot and refer to each column by name. For example, if you were to plot the column 'price' vs the column 'area' from a DataFrame df, you could call sns.lmplot(x='area', y='price', data=df)

# %% [markdown]
# ## Visualizing regressions

# %% [markdown]
# ### Simple linear regressions

# %%
import matplotlib.pyplot as plt


sns.lmplot(x='weight', y='hp', data=auto)

plt.show()

# %% [markdown]
# ### Plotting residuals of a regression
#
#  Often, you don't just want to see the regression itself but also see the residuals to get a better idea how well the regression captured the data. Seaborn provides sns.residplot() for that purpose, visualizing how far datapoints diverge from the regression line.

# %%
sns.residplot(x='hp', y='mpg', data=auto, color='green')

# %% [markdown]
# ### Higher-order regressions

# %% [markdown]
# When there are more complex relationships between two variables, a simple first order regression is often not sufficient to accurately capture the relationship between the variables. Seaborn makes it simple to compute and visualize regressions of varying orders.
#
# Here, you will plot a second order regression between the horse power ('hp') and miles per gallon ('mpg') using sns.regplot() (the function sns.lmplot() is a higher-level interface to sns.regplot()). However, before plotting this relationship, compare how the residual changes depending on the order of the regression. Does a second order regression perform significantly better than a simple linear regression?
#
# * A principal difference between sns.lmplot() and sns.regplot() is the way in which matplotlib options are passed (sns.regplot() is more permissive).
# * For both sns.lmplot() and sns.regplot(), the keyword order is used to control the order of polynomial regression.
# * The function sns.regplot() uses the argument scatter=None to prevent plotting the scatter plot points again.

# %%
plt.scatter(auto['weight'], auto['mpg'], 
            label='data', color='red', marker='o')

sns.regplot(x='weight', y='mpg', data=auto, 
            color='blue', scatter=None, order=1, label='order 1')

sns.regplot(x='weight', y='mpg', data=auto, 
            color='green', scatter=None, order=2, label='order 2')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Grouping linear regressions by hue

# %% [markdown]
# Often it is useful to compare and contrast trends between different groups. Seaborn makes it possible to apply linear regressions separately for subsets of the data by applying a groupby operation. Using the hue argument, you can specify a categorical variable by which to group data observations. The distinct groups of points are used to produce distinct regressions with different hues in the plot.

# %%
sns.lmplot(x='weight', y='hp', hue='origin', data=auto, 
           palette='Set1')

# %% [markdown]
# ### Grouping linear regressions by row or column

# %% [markdown]
# Rather than overlaying linear regressions of grouped data in the same plot, we may want to use a grid of subplots. The sns.lmplot() accepts the arguments row and/or col to arrangements of subplots for regressions.
#
# You'll use the automobile dataset again and, this time, you'll use the keyword argument row to display the subplots organized in rows. That is, you'll produce horsepower vs. weight regressions grouped by continent of origin in separate subplots stacked vertically.

# %%
sns.lmplot(x='weight', y='hp', row='origin', data=auto)

# %% [markdown]
# ## Visualizing univariate distributions

# %% [markdown]
# ### Constructing strip plots

# %% [markdown]
# * For example, sns.stripplot(x='type', y='length', data=df) produces a sequence of vertical strip plots of length distributions grouped by type (assuming length is a continuous column and type is a categorical column of the DataFrame df).
# * Overlapping points can be difficult to distinguish in strip plots. The argument jitter=True helps spread out overlapping points.
# * Other matplotlib arguments can be passed to sns.stripplot(), e.g., marker, color, size, etc.

# %%
plt.subplot(2,1,1)
sns.stripplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=3)

# %% [markdown]
# ### Constructing swarm plots

# %% [markdown]
# * The syntax for sns.swarmplot() is similar to that of sns.stripplot(), e.g., sns.swarmplot(x='type', y='length', data=df).
# * The orientation for the continuous variable in the strip/swarm plot can be inferred from the choice of the columns x and y from the DataFrame data. The orientation can be set explicitly using orient='h' (horizontal) or orient='v' (vertical).
# * Another grouping can be added in using the hue keyword. For instance, using sns.swarmplot(x='type', y='length', data=df, hue='build year') makes a swarm plot from the DataFrame df with the 'length' column values spread out vertically, horizontally grouped by the column 'type' and each point colored by the categorical column 'build year'.

# %%
plt.subplot(2,1,1)
sns.swarmplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.swarmplot(y='cyl', x='hp', data=auto, hue='origin', orient='h')

# %% [markdown]
# ### Constructing violin plots

# %% [markdown]
# Both strip and swarm plots visualize all the datapoints. For large datasets, this can result in significant overplotting. Therefore, it is often useful to use plot types which reduce a dataset to more descriptive statistics and provide a good summary of the data.

# %%
plt.subplot(2,1,1)
sns.violinplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
sns.violinplot(x='cyl', y='hp', data=auto, inner=None, color='lightgray')

sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=1.5)

# %% [markdown]
# ## Visualizing multivariate distributions

# %% [markdown]
# ### Plotting joint distributions (1)

# %% [markdown]
# There are numerous strategies to visualize how pairs of continuous random variables vary jointly. Regression and residual plots are one strategy. Another is to visualize a bivariate distribution.
#
# Seaborn's sns.jointplot() provides means of visualizing bivariate distributions. The basic calling syntax is similar to that of sns.lmplot(). By default, calling sns.jointplot(x, y, data) renders a few things:
#
# * A scatter plot using the specified columns x and y from the DataFrame data.
# * A (univariate) histogram along the top of the scatter plot showing distribution of the column x.
# * A (univariate) histogram along the right of the scatter plot showing distribution of the column y.

# %%
sns.jointplot(x='hp', y='mpg', data=auto)

# %% [markdown]
# ### Plotting joint distributions (2), kind param

# %% [markdown]
# The seaborn function sns.jointplot() has a parameter kind to specify how to visualize the joint variation of two continuous random variables (i.e., two columns of a DataFrame)
#
# * kind='scatter' uses a scatter plot of the data points
# * kind='reg' uses a regression plot (default order 1)
# * kind='resid' uses a residual plot
# * kind='kde' uses a kernel density estimate of the joint distribution
# * kind='hex' uses a hexbin plot of the joint distribution

# %%
kind = ['scatter', 'hex', 'reg', 'resid', 'kde']

[(index, val) for (index, val) in enumerate(kind)]
# Out:
# [(0, 'scatter'), (1, 'hex'), (2, 'reg'), (3, 'resid'), (4, 'kde')]

# %%
sns.jointplot(x='hp', y='mpg', data=auto, kind='hex')

# %%
sns.jointplot(x='hp', y='mpg', data=auto, kind='reg')

# %%
sns.jointplot(x='hp', y='mpg', data=auto, kind='resid')

# %%
sns.jointplot(x='hp', y='mpg', data=auto, kind='kde')

# %% [markdown]
# ### Plotting distributions pairwise (1)

# %% [markdown]
# Data sets often contain more than two continuous variables. The function sns.jointplot() is restricted to representing joint variation between only two quantities (i.e., two columns of a DataFrame). Visualizing multivariate relationships is trickier.
#
# The function sns.pairplot() constructs a grid of all joint plots pairwise from all pairs of (non-categorical) columns in a DataFrame. The syntax is very simple: sns.pairplot(df), where df is a DataFrame. The non-categorical columns are identified and the corresponding joint plots are plotted in a square grid of subplots. The diagonal of the subplot grid shows the univariate histograms of the individual columns.

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 12 columns):
# mpg       392 non-null float64
# cyl       392 non-null int64
# displ     392 non-null float64
# hp        392 non-null int64
# weight    392 non-null int64
# accel     392 non-null float64
# yr        392 non-null int64
# origin    392 non-null object
# name      392 non-null object
# color     392 non-null object
# size      392 non-null float64
# marker    392 non-null object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 36.8+ KB

# %%
auto.cyl = auto.cyl.astype('category')
auto.yr = auto.yr.astype('category')

# %%
sns.pairplot(auto[['mpg', 'displ', 'hp', ]])

# %% [markdown]
# ### Plotting distributions pairwise (2)

# %%
sns.pairplot(auto[['mpg', 'displ', 'hp','origin']], 
             hue='origin', kind='reg')

# %% [markdown]
# ### Visualizing correlations with a heatmap

# %% [markdown]
# Plotting relationships between many variables using a pair plot can quickly get visually overwhelming. It is therefore often useful to compute covariances between the variables instead. The covariance matrix can then easily be visualized as a heatmap. A heatmap is effectively a pseudocolor plot with labelled rows and columns (i.e., a pseudocolor plot based on a pandas DataFrame rather than a matrix). The DataFrame does not have to be square or symmetric (but, in the context of a covariance matrix, it is both).

# %%
auto.corr()
# Out:
#              mpg     displ        hp    weight     accel      size
# mpg     1.000000 -0.805127 -0.778427 -0.832244  0.423329 -0.806682
# displ  -0.805127  1.000000  0.897257  0.932994 -0.543800  0.928779
# hp     -0.778427  0.897257  1.000000  0.864538 -0.689196  0.869720
# weight -0.832244  0.932994  0.864538  1.000000 -0.416839  0.992019
# accel   0.423329 -0.543800 -0.689196 -0.416839  1.000000 -0.426547
# size   -0.806682  0.928779  0.869720  0.992019 -0.426547  1.000000

# %%
sns.heatmap(auto.corr(), cmap='summer')

# %% [markdown]
# # Analyzing time series and images

# %% [markdown]
# ## Visualizing time series

# %% [markdown]
# ### Multiple time series on common axes

# %%
stk = pd.read_csv('stocks.csv', parse_dates=True, index_col='Date')
stk.head()
# Out:
#                   AAPL       IBM      CSCO      MSFT
# Date
# 2000-01-03  111.937502  116.0000  108.0625  116.5625
# 2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2000-01-05  103.999997  116.0000  101.6875  113.8125
# 2000-01-06   94.999998  114.0000  100.0000  110.0000
# 2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
stk.columns = [x.lower() for x in stk.columns]

# %%
stk.index  # note dtype='datetime'
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2013-12-17', '2013-12-18', '2013-12-19', '2013-12-20',
#                '2013-12-23', '2013-12-24', '2013-12-26', '2013-12-27',
#                '2013-12-30', '2013-12-31'],
#               dtype='datetime64[ns]', name='Date', length=3521, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(stk.aapl, color='blue', label='AAPL')

plt.plot(stk.ibm, color='green', label='IBM')

plt.plot(stk.csco, color='red', label='CSCO')

plt.plot(stk.msft, color='magenta', label='MSFT')

plt.legend(loc='upper left')

plt.xticks(rotation=60)
# Out:
# (array([ 730486.,  731216.,  731947.,  732677.,  733408.,  734138.,  734869.]),
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ### Multiple time series slices (1)

# %% [markdown]
# You can easily slice subsets corresponding to different time intervals from a time series. In particular, you can use strings like '2001:2005', '2011-03:2011-12', or '2010-04-19:2010-04-30' to extract data from time intervals of length 5 years, 10 months, or 12 days respectively.
#
# * Unlike slicing from standard Python lists, tuples, and strings, when slicing time series by labels (and other pandas Series & DataFrames by labels), the slice includes the right-most portion of the slice. That is, extracting my_time_series['1990':'1995'] extracts data from my_time_series corresponding to 1990, 1991, 1992, 1993, 1994, and 1995 inclusive.
# * You can use partial strings or datetime objects for indexing and slicing from time series.

# %%
plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('AAPL: 2001 to 2011')
plt.plot(stk.aapl, color='blue')

view = stk.aapl['2007':'2008']

plt.subplot(2,1,2)
plt.xticks(rotation=45)
plt.title('AAPL: 2007 to 2008')
plt.plot(view, color='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multiple time series slices (2)

# %% [markdown]
# * Partial string indexing works without slicing as well. For instance, using my_time_series['1995'], my_time_series['1999-05'], and my_time_series['2000-11-04'] respectively extracts views of the time series my_time_series corresponding to the entire year 1995, the entire month May 1999, and the entire day November 4, 2000.

# %%
view = stk.aapl['2007-11':'2008-04']

plt.subplot(2,1,1)
plt.plot(view, color='red', )
plt.title('AAPL: Nov. 2007 to Apr. 2008')
plt.xticks(rotation=45)

view = stk.aapl['2008-01']

plt.subplot(2,1,2)
plt.plot(view, color='green')
plt.title('AAPL: Jan. 2008')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting an inset view

# %% [markdown]
# Rather than comparing plots with subplots or overlayed plots, you can generate an inset view directly using plt.axes()

# %%
view = stk.aapl['2007-11':'2008-04']

plt.plot(stk.aapl)           # plot the whole series
plt.xticks(rotation=45)
plt.title('AAPL: 2001-2011')

plt.axes([0.25, 0.5, 0.35, 0.35])
                            # add an inner view
                            # [x_start, y_start, x_span, y_span]

plt.plot(view, color='red')
plt.xticks(rotation=45)
plt.title('2007/11-2008/04')
plt.show()

# %% [markdown]
# ## Time series with moving windows

# %% [markdown]
# ### Plotting moving averages

# %%
mean_30 = stk.aapl.rolling(window=30).mean()
    # Series.rolling(window=n).aggfunc(), 
    # transform a series, take in each value, 
    # return aggfunc([n_vals_backward]) 
mean_75 = stk.aapl.rolling(window=75).mean()
mean_125 = stk.aapl.rolling(window=125).mean()
mean_250 = stk.aapl.rolling(window=250).mean()

# %%
print(np.sum(pd.isnull(mean_30)), 
      np.sum(pd.isnull(mean_75)), 
      np.sum(pd.isnull(mean_125)), 
      np.sum(pd.isnull(mean_250)) )
# Out:
# 29 74 124 249

# %%
plt.subplot(2,2,1)
plt.plot(mean_30, 'green')
plt.plot(aapl, 'k-.', alpha=0.5)
plt.xticks(rotation=60)
plt.title('30d averages')

plt.subplot(2,2,2)
plt.plot(mean_75, 'red')
plt.plot(aapl, 'k-.', alpha=0.5)
plt.xticks(rotation=60)
plt.title('75d averages')

plt.subplot(2, 2, 3)
plt.plot(mean_125, 'magenta')
plt.plot(aapl, 'k-.', alpha=0.5)
plt.xticks(rotation=60)
plt.title('125d averages')

plt.subplot(2,2,4)
plt.plot(mean_250, 'cyan')
plt.plot(aapl, 'k-.', alpha=0.5)
plt.xticks(rotation=60)
plt.title('250d averages')

plt.show()

# %% [markdown]
# ### Plotting moving standard deviations

# %%
std_30 = stk.aapl.rolling(window=30).std()
std_75 = stk.aapl.rolling(window=75).std()
std_125 = stk.aapl.rolling(window=125).std()
std_250 = stk.aapl.rolling(window=250).std()

# %%
plt.plot(std_30, color='red', label='30d')
plt.plot(std_75, color='cyan', label='75d')
plt.plot(std_125, color='green', label='125d')
plt.plot(std_250, color='magenta', label='250d')

plt.legend(loc='upper left')

plt.title('Moving standard deviations')

# %% [markdown]
# ## Histogram equalization in images

# %% [markdown]
# ### Extracting a histogram from a grayscale image

# %%
image = plt.imread('hawk.jpg')

plt.subplot(2,1,1)
plt.title('Original image')
plt.axis('off')
plt.imshow(image, cmap='gray')

pixels = image.flatten()

plt.subplot(2,1,2)
plt.xlim((0,255))
plt.title('Normalized histogram')
plt.hist(pixels, bins=64, range=(0,256), normed=True, color='red', alpha=0.4)

plt.show()

# %% [markdown]
# ### Cumulative Distribution Function from an image histogram

# %%
plt.subplot(2,1,1)
plt.imshow(image, cmap='gray')
plt.title('Original image')
plt.axis('off')

pixels = image.flatten()

plt.subplot(2,1,2)
pdf = plt.hist(pixels, bins=64, range=(0,256), normed=True,
               color='red', alpha=0.4)
plt.grid('off')

    # Use plt.twinx() to overlay the CDF in the bottom subplot
plt.twinx()

    # Display a cumulative histogram of the pixels
cdf = plt.hist(pixels, bins=64, range=(0,256),
               normed=True, cumulative=True,
               color='blue', alpha=0.4)
               
plt.xlim((0,256))
plt.grid('off')
plt.title('PDF & CDF (original image)')
plt.show()

# %% [markdown]
# ### Equalizing an image histogram

# %% [markdown]
# Histogram equalization is an image processing procedure that reassigns image pixel intensities. The basic idea is to use interpolation to map the original CDF of pixel intensities to a CDF that is almost a straight line. In essence, the pixel intensities are spread out and this has the practical effect of making a sharper, contrast-enhanced image. This is particularly useful in astronomy and medical imaging to help us see more features.
#
# 【不是很懂】

# %%
cdf, bins, patches = plt.hist(pixels, bins=256, range=(0,256), normed=True, cumulative=True)
new_pixels = np.interp(pixels, bins[:-1], cdf*255)

new_image = new_pixels.reshape(image.shape)

plt.subplot(2,1,1)
plt.title('Equalized image')
plt.axis('off')
plt.imshow(new_image, cmap='gray')

plt.subplot(2,1,2)
pdf = plt.hist(new_pixels, bins=64, range=(0,256),
normed=False,
               color='red', alpha=0.4)
plt.grid('off')

plt.twinx()
plt.xlim((0,256))
plt.grid('off')

plt.title('PDF & CDF (equalized image)')

cdf = plt.hist(new_pixels, bins=64, range=(0,256),
               cumulative=True, normed=True,
               color='blue', alpha=0.4)
plt.show()

# %% [markdown]
# ### Extracting color channels histograms from a color image

# %%
avatar = plt.imread('avatar.jpg')

plt.subplot(2,1,1)
plt.title('Original image')
plt.axis('off')
plt.imshow(avatar)

red, green, blue = avatar[:,:,0], avatar[:,:,1], avatar[:,:,2]

red_pixels = red.flatten()
green_pixels = green.flatten()
blue_pixels = blue.flatten()

plt.subplot(2,1,2)
plt.title('Histograms from color image')
plt.xlim((0,256))
plt.hist(red_pixels, bins=64, normed=True, color='red', alpha=0.2)
plt.hist(blue_pixels, bins=64, normed=True, color='blue', alpha=0.2)
plt.hist(green_pixels, bins=64, normed=True, color='green', alpha=0.2)

plt.show()

# %% [markdown]
# ### Extracting bivariate histograms from a color image

# %% [markdown]
# Rather than overlaying univariate histograms of intensities in distinct channels, it is also possible to view the joint variation of pixel intensity in two different channels.

# %%
space = plt.imread('space.jpg')

# %%
plt.style.use('ggplot')

red, blue, green = space[:,:,0], space[:,:,1], space[:,:,2]
red_pixels = red.flatten()
blue_pixels = blue.flatten()
green_pixels = green.flatten()

plt.subplot(2,2,1)
plt.xticks(rotation=60)
plt.xlabel('red')
plt.ylabel('green')
plt.hist2d(red_pixels, green_pixels, bins=(100, 100))
plt.colorbar()

plt.subplot(2,2,2)
plt.xticks(rotation=60)
plt.xlabel('green')
plt.ylabel('blue')
plt.hist2d(green_pixels, blue_pixels, bins=(32, 32))
plt.colorbar()

plt.subplot(2,2,3)
plt.xticks(rotation=60)
plt.xlabel('blue')
plt.ylabel('red')
plt.hist2d(blue_pixels, red_pixels, bins=(32,32))
plt.colorbar()

plt.show()

# %% [markdown]
# # end
